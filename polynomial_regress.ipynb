# %% [markdown]
# Machine Learning - Polynomial Regression

# %% [markdown]
# Polynomial Regression
#
# If your data points clearly will not fit a linear regression (a straight line through all data points), it might be ideal for polynomial regression.
#
# Polynomial regression, like linear regression, uses the relationship between the variables x and y to find the best way to draw a line through the data points.

# %%
from IPython.display import Image, display

display(Image(filename="Capture.PNG"))

# %% [markdown]
# How Does it Work?
#
# Python has methods for finding a relationship between data-points and to draw a line of polynomial regression. We will show you how to use these methods instead of going through the mathematic formula.
#
# In the example below, we have registered 18 cars as they were passing a certain tollbooth.
#
# We have registered the car's speed, and the time of day (hour) the passing occurred.
#
# The x-axis represents the hours of the day and the y-axis represents the speed:

# %%
import matplotlib.pyplot as plt

x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

plt.scatter(x, y)
plt.show()

# %% [markdown]
# Import numpy and matplotlib then draw the line of Polynomial Regression:

# %%
import numpy  # NumPy: used for numerical computations (polynomial fitting, array creation).
import matplotlib.pyplot as plt  # Matplotlib: used for plotting graphs.

# %%
x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

# %%
mymodel = numpy.poly1d(numpy.polyfit(x, y, 3))

# %% [markdown]
# This is the core of the code:
#
# numpy.polyfit(x, y, 3)
#
# Fits a 3rd-degree polynomial to the data.
#
# Finds the best polynomial equation:
#
# Returns the coefficients [a, b, c, d].
#
# numpy.poly1d(...)
#
# Converts those coefficients into a callable function.
#
# Now mymodel(x) can predict y for any value of x.

# %%
myline = numpy.linspace(1, 22, 100)

# %% [markdown]
# Generates 100 evenly spaced values between 1 and 22.
#
# Used to draw a smooth curve instead of jagged points.

# %%
plt.scatter(x, y)

# Creates a scatter plot of actual data points.

 # Shows raw observations.

# %%
plt.plot(myline, mymodel(myline))
plt.show()

# %%
# Complete code

import numpy
import matplotlib.pyplot as plt

x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

mymodel = numpy.poly1d(numpy.polyfit(x, y, 3))

plt.scatter(x, y)
plt.plot(x, mymodel(x))
plt.show()
